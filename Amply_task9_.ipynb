# %% [markdown]
# ## **Align Guard Internship**
#
# **Inertia Sensors For human Activity - Cycling**
#
# * Created By : Blessy louis
# * Email: blessylouis2002@gmail.com
# * Created On: 11.06.2024
#
#
#
# ---

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Load Dataset

# %% [markdown]
# The dataset for Inertia Sensors for Human Activity Recognition in specific to cycling captures various inertial sensor readings along with time-based features. Here is a detailed description of the features provided in the dataset:
#
# ### Features Description:
#
# 1. **ACCELEROMETER X (m/s²)**:
#    - **Description**: Measures acceleration along the X-axis in meters per second squared (m/s²).
#    - **Typical Range**: The values typically range depending on the motion dynamics and the orientation of the sensor.
#
# 2. **ACCELEROMETER Y (m/s²)**:
#    - **Description**: Measures acceleration along the Y-axis in meters per second squared (m/s²).
#    - **Typical Range**: Similar to the X-axis, the range varies with the cycling dynamics.
#
# 3. **ACCELEROMETER Z (m/s²)**:
#    - **Description**: Measures acceleration along the Z-axis in meters per second squared (m/s²).
#    - **Typical Range**: Values change based on the vertical movements and gravity.
#
# 4. **GRAVITY X (m/s²)**:
#    - **Description**: Measures the gravitational component along the X-axis in meters per second squared (m/s²).
#    - **Typical Range**: Generally ranges from -9.8 to 9.8 m/s², depending on the sensor orientation.
#
# 5. **GRAVITY Y (m/s²)**:
#    - **Description**: Measures the gravitational component along the Y-axis in meters per second squared (m/s²).
#    - **Typical Range**: Similar to the X-axis, typically ranges within the gravitational acceleration limits.
#
# 6. **GRAVITY Z (m/s²)**:
#    - **Description**: Measures the gravitational component along the Z-axis in meters per second squared (m/s²).
#    - **Typical Range**: Around -9.8 m/s² (aligned with gravity) to 9.8 m/s² (opposite to gravity).
#
# 7. **LINEAR ACCELERATION X (m/s²)**:
#    - **Description**: Measures the linear acceleration (acceleration without gravity) along the X-axis in meters per second squared (m/s²).
#    - **Typical Range**: Values depend on the specific cycling movements.
#
# 8. **LINEAR ACCELERATION Y (m/s²)**:
#    - **Description**: Measures the linear acceleration along the Y-axis in meters per second squared (m/s²).
#    - **Typical Range**: Reflects horizontal acceleration due to pedaling and turning.
#
# 9. **LINEAR ACCELERATION Z (m/s²)**:
#    - **Description**: Measures the linear acceleration along the Z-axis in meters per second squared (m/s²).
#    - **Typical Range**: Indicates vertical acceleration, useful for detecting jumps or bumps.
#
# 10. **GYROSCOPE X (rad/s)**:
#     - **Description**: Measures angular velocity around the X-axis in radians per second (rad/s).
#     - **Typical Range**: Values can range widely based on the rotational speed of the cyclist.
#
# 11. **GYROSCOPE Y (rad/s)**:
#     - **Description**: Measures angular velocity around the Y-axis in radians per second (rad/s).
#     - **Typical Range**: Indicates rotational movements related to leaning or swaying.
#
# 12. **GYROSCOPE Z (rad/s)**:
#     - **Description**: Measures angular velocity around the Z-axis in radians per second (rad/s).
#     - **Typical Range**: Reflects yaw movements (turning left or right).
#
# 13. **Time since start in ms**:
#     - **Description**: Represents the elapsed time since the start of the recording in milliseconds.
#     - **Typical Range**: Starts from 0 and increments with each data sample.
#
# 14. **YYYY-MO-DD HH-MI-SS_SSS**:
#     - **Description**: Timestamp of the data sample in the format year-month-day hour-minute-second-millisecond.
#     - **Typical Range**: Varies based on the actual recording time, providing the exact time each sample was captured.

# %%
df=pd.read_csv('Cycling.csv')

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                 -0.8857                 -0.9150                  9.5503
# 1                 -0.8139                  1.2541                  9.4306
# 2                -10.2466                -11.1079                 16.0610
# 3                 -4.3679                 -7.6616                 -4.6180
# 4                  5.0936                 -7.1863                 -5.2249
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0           -1.1034           -0.0603            9.7442
# 1           -0.5532            1.0615            9.7333
# 2            0.9801            6.8492           -6.9497
# 3            3.5523           -8.1039           -4.2283
# 4            4.0020           -8.0153           -3.9886
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                       -0.6645                        0.8831
# ...

# %%
df.tail()
# Out:
#       ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 6759                  -0.484                   3.788                   9.086
# 6760                  -0.524                   3.768                  10.525
# 6761                  -2.392                   3.888                   7.961
# 6762                   0.639                   2.413                   8.193
# 6763                   1.556                   3.508                   7.994
#
#       GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 6759             0.328             3.704             9.074
# 6760            -0.708             3.133             9.266
# 6761            -0.640             3.489             9.143
# 6762            -0.673             2.937             9.332
# 6763             1.669             4.051             8.774
#
#       LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 6759                        -0.811                         0.083
# ...

# %%
df.columns
# Out:
# Index(['ACCELEROMETER X (m/s²)', 'ACCELEROMETER Y (m/s²)',
#        'ACCELEROMETER Z (m/s²)', 'GRAVITY X (m/s²)', 'GRAVITY Y (m/s²)',
#        'GRAVITY Z (m/s²)', 'LINEAR ACCELERATION X (m/s²)',
#        'LINEAR ACCELERATION Y (m/s²)', 'LINEAR ACCELERATION Z (m/s²)',
#        'GYROSCOPE X (rad/s)', 'GYROSCOPE Y (rad/s)', 'GYROSCOPE Z (rad/s)',
#        'Time since start in ms ', 'YYYY-MO-DD HH-MI-SS_SSS'],
#       dtype='object')

# %%
df.shape
# Out:
# (6764, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6764 entries, 0 to 6763
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ACCELEROMETER X (m/s²)        6764 non-null   float64
#  1   ACCELEROMETER Y (m/s²)        6764 non-null   float64
#  2   ACCELEROMETER Z (m/s²)        6764 non-null   float64
#  3   GRAVITY X (m/s²)              6764 non-null   float64
#  4   GRAVITY Y (m/s²)              6764 non-null   float64
#  5   GRAVITY Z (m/s²)              6764 non-null   float64
#  6   LINEAR ACCELERATION X (m/s²)  6764 non-null   float64
#  7   LINEAR ACCELERATION Y (m/s²)  6764 non-null   float64
#  8   LINEAR ACCELERATION Z (m/s²)  6764 non-null   float64
#  9   GYROSCOPE X (rad/s)           6764 non-null   float64
#  10  GYROSCOPE Y (rad/s)           6764 non-null   float64
#  11  GYROSCOPE Z (rad/s)           6764 non-null   float64
# ...

# %%
df.describe()
# Out:
#        ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# count             5824.000000             5824.000000             5824.000000
# mean                -1.508320               -0.309640               -3.593378
# std                  6.300048                7.168224                3.898752
# min                -25.096000              -43.865200              -32.346000
# 25%                 -5.929100               -6.428600               -5.569600
# 50%                 -2.105400               -1.100150               -2.738000
# 75%                  1.821125                6.170500               -1.115325
# max                 33.693600               31.520000               16.061000
#
#        GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# count       5824.000000       5824.000000       5824.000000
# mean          -1.586181         -0.181341         -3.702968
# std            5.464396          6.245926          3.324407
# ...

# %%
df.isnull().sum()
# Out:
# ACCELEROMETER X (m/s²)          0
# ACCELEROMETER Y (m/s²)          0
# ACCELEROMETER Z (m/s²)          0
# GRAVITY X (m/s²)                0
# GRAVITY Y (m/s²)                0
# GRAVITY Z (m/s²)                0
# LINEAR ACCELERATION X (m/s²)    0
# LINEAR ACCELERATION Y (m/s²)    0
# LINEAR ACCELERATION Z (m/s²)    0
# GYROSCOPE X (rad/s)             0
# GYROSCOPE Y (rad/s)             0
# GYROSCOPE Z (rad/s)             0
# Time since start in ms          0
# YYYY-MO-DD HH-MI-SS_SSS         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 940

# %%
# Remove duplicates (keeps the first occurrence)
df.drop_duplicates(inplace=True)

# Print the data after removing duplicates
print("\nData after removing duplicates:")
print(df)

print("Number of duplicates after removal",df.duplicated().sum())
# Out:
# Data after removing duplicates:
#       ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                    -0.8857                 -0.9150                  9.5503
# 1                    -0.8139                  1.2541                  9.4306
# 2                   -10.2466                -11.1079                 16.0610
# 3                    -4.3679                 -7.6616                 -4.6180
# 4                     5.0936                 -7.1863                 -5.2249
# ...                      ...                     ...                     ...
# 6759                 -0.4840                  3.7880                  9.0860
# 6760                 -0.5240                  3.7680                 10.5250
# 6761                 -2.3920                  3.8880                  7.9610
# 6762                  0.6390                  2.4130                  8.1930
# 6763                  1.5560                  3.5080                  7.9940
#
# ...

# %%
# Select the first three columns for accelerometer data
accelerometer_df = df.iloc[:, 0:3]

# Select the next three columns for gravity data
gravity_df = df.iloc[:, 3:6]

# Select the next three columns for linear acceleration data
linear_acceleration_df = df.iloc[:, 6:9]

# Select the next three columns for gyroscope data
gyroscope_df = df.iloc[:, 9:12]

# %% [markdown]
# # Handling Skewness

# %%
# Calculate skewness
def calculate_skewness(dataframe):
    return dataframe.skew()

# Plot histograms and Q-Q plots
def plot_histogram_and_qq(dataframe, title):
    num_cols = dataframe.shape[1]
    plt.figure(figsize=(18, 6 * num_cols))

    for i, column in enumerate(dataframe.columns):
        plt.subplot(num_cols, 2, 2 * i + 1)
        sns.histplot(dataframe[column], kde=True)
        plt.title(f'Histogram of {column}')

        plt.subplot(num_cols, 2, 2 * i + 2)
        stats.probplot(dataframe[column], dist="norm", plot=plt)
        plt.title(f'Q-Q Plot of {column}')

    plt.suptitle(f'{title} DataFrame', y=1.02, fontsize=20)
    plt.tight_layout()
    plt.show()

# Calculate and plot for each sub-dataframe
print("Skewness for Accelerometer DataFrame:\n", calculate_skewness(accelerometer_df))
plot_histogram_and_qq(accelerometer_df, 'Accelerometer')

print("Skewness for Gravity DataFrame:\n", calculate_skewness(gravity_df))
plot_histogram_and_qq(gravity_df, 'Gravity')

print("Skewness for Linear Acceleration DataFrame:\n", calculate_skewness(linear_acceleration_df))
plot_histogram_and_qq(linear_acceleration_df, 'Linear Acceleration')

print("Skewness for Gyroscope DataFrame:\n", calculate_skewness(gyroscope_df))
plot_histogram_and_qq(gyroscope_df, 'Gyroscope')
# Out:
# Skewness for Accelerometer DataFrame:
#  ACCELEROMETER X (m/s²)    0.591250
# ACCELEROMETER Y (m/s²)    0.067714
# ACCELEROMETER Z (m/s²)   -0.550701
# dtype: float64
# Skewness for Gravity DataFrame:
#  GRAVITY X (m/s²)    0.499836
# GRAVITY Y (m/s²)    0.106632
# GRAVITY Z (m/s²)   -0.120026
# dtype: float64
# Skewness for Linear Acceleration DataFrame:
#  LINEAR ACCELERATION X (m/s²)    0.070470
# LINEAR ACCELERATION Y (m/s²)   -0.203312
# LINEAR ACCELERATION Z (m/s²)    0.687621
# dtype: float64
# Skewness for Gyroscope DataFrame:
#  GYROSCOPE X (rad/s)   -0.054370
# GYROSCOPE Y (rad/s)   -0.663375
# GYROSCOPE Z (rad/s)   -0.141489
# dtype: float64

# %%
# Calculate skewness for numerical columns
skewness = df.skew(numeric_only=True)
# Separate columns based on skewness
positive_skew_columns = skewness[skewness > 0].index
negative_skew_columns = skewness[skewness < 0].index

positive_skew_df = df[positive_skew_columns]
negative_skew_df = df[negative_skew_columns]

print("Columns with positive skewness:\n", positive_skew_columns)
print("Columns with negative skewness:\n", negative_skew_columns)
# Out:
# Columns with positive skewness:
#  Index(['ACCELEROMETER X (m/s²)', 'ACCELEROMETER Y (m/s²)', 'GRAVITY X (m/s²)',
#        'GRAVITY Y (m/s²)', 'LINEAR ACCELERATION X (m/s²)',
#        'LINEAR ACCELERATION Z (m/s²)', 'Time since start in ms '],
#       dtype='object')
# Columns with negative skewness:
#  Index(['ACCELEROMETER Z (m/s²)', 'GRAVITY Z (m/s²)',
#        'LINEAR ACCELERATION Y (m/s²)', 'GYROSCOPE X (rad/s)',
#        'GYROSCOPE Y (rad/s)', 'GYROSCOPE Z (rad/s)'],
#       dtype='object')

# %% [markdown]
# # Log Transformation

# %%
# Calculate initial skewness for positive skewness dataframe
initial_positive_skewness = positive_skew_df.skew()


# Apply log transformation to positive skewness dataframe
transformed_positive_skew_df = np.log1p(positive_skew_df)

# Calculate skewness after transformation
transformed_positive_skewness = transformed_positive_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_positive_skewness,
    'Transformed Skewness': transformed_positive_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)

# Plot histograms
def plot_histogram_and_qq(dataframe, title):
    num_cols = dataframe.shape[1]
    plt.figure(figsize=(18, 6 * num_cols))

    for i, column in enumerate(dataframe.columns):
        plt.subplot(num_cols, 2, 2 * i + 1)
        sns.histplot(dataframe[column], kde=True)
        plt.title(f'Histogram of {column}')


    plt.suptitle(f'{title} DataFrame', y=1.02, fontsize=20)
    plt.tight_layout()
    plt.show()

# Plot histograms and Q-Q plots for transformed positive skewness dataframe
plot_histogram_and_qq(transformed_positive_skew_df, '\nTransformed Positive Skewness')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: divide by zero encountered in log1p
#   result = func(self.values, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER X (m/s²)                0.591250             -1.510215
# ACCELEROMETER Y (m/s²)                0.067714             -2.106839
# GRAVITY X (m/s²)                      0.499836             -1.950052
# GRAVITY Y (m/s²)                      0.106632             -2.190732
# LINEAR ACCELERATION X (m/s²)          0.070470             -1.100565
# LINEAR ACCELERATION Z (m/s²)          0.687621                   NaN
# Time since start in ms                0.269263             -2.076369

# %% [markdown]
# # Reciporcal Transformation

# %%
# Calculate initial skewness for positive skewness dataframe
initial_positive_skewness = positive_skew_df.skew()


# Apply reciprocal transformation to positive skewness dataframe
transformed_positive_skew_df = 1 / (positive_skew_df + 1)

# Calculate skewness after transformation
transformed_positive_skewness = transformed_positive_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_positive_skewness,
    'Transformed Skewness': transformed_positive_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)
# Out:
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER X (m/s²)                0.591250             45.061470
# ACCELEROMETER Y (m/s²)                0.067714            -59.640013
# GRAVITY X (m/s²)                      0.499836             67.165071
# GRAVITY Y (m/s²)                      0.106632             47.652067
# LINEAR ACCELERATION X (m/s²)          0.070470            -58.841953
# LINEAR ACCELERATION Z (m/s²)          0.687621                   NaN
# Time since start in ms                0.269263             45.116644

# %% [markdown]
# # Square Root Transformation

# %%
# Calculate initial skewness for positive skewness dataframe
initial_positive_skewness = positive_skew_df.skew()


# Apply square root transformation to positive skewness dataframe
transformed_positive_skew_df = np.sqrt(positive_skew_df)

# Calculate skewness after transformation
transformed_positive_skewness = transformed_positive_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_positive_skewness,
    'Transformed Skewness': transformed_positive_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)
# Out:
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER X (m/s²)                0.591250              0.083546
# ACCELEROMETER Y (m/s²)                0.067714             -0.559886
# GRAVITY X (m/s²)                      0.499836             -0.767311
# GRAVITY Y (m/s²)                      0.106632             -0.815538
# LINEAR ACCELERATION X (m/s²)          0.070470              0.840299
# LINEAR ACCELERATION Z (m/s²)          0.687621              1.289712
# Time since start in ms                0.269263             -0.346602
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)

# %% [markdown]
# # Power Transformation

# %%
# Calculate initial skewness for negative skewness dataframe
initial_negative_skewness = negative_skew_df.skew()


# Apply power transformation to negative skewness dataframe
transformed_negative_skew_df = negative_skew_df.apply(lambda x: np.power(x, 0.5))

# Calculate skewness after transformation
transformed_negative_skewness = transformed_negative_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_negative_skewness,
    'Transformed Skewness': transformed_negative_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)
# Out:
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER Z (m/s²)               -0.550701              1.292722
# GRAVITY Z (m/s²)                     -0.120026              1.607710
# LINEAR ACCELERATION Y (m/s²)         -0.203312              0.652016
# GYROSCOPE X (rad/s)                  -0.054370              0.931747
# GYROSCOPE Y (rad/s)                  -0.663375              0.588797
# GYROSCOPE Z (rad/s)                  -0.141489              0.537237

# %% [markdown]
# # Exponential transformation

# %%
# Calculate initial skewness for negative skewness dataframe
initial_negative_skewness = negative_skew_df.skew()


# Apply exponential transformation to negative skewness dataframe
transformed_negative_skew_df = np.exp(negative_skew_df)

# Calculate skewness after transformation
transformed_negative_skewness = transformed_negative_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_negative_skewness,
    'Transformed Skewness': transformed_negative_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)
# Out:
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER Z (m/s²)               -0.550701             74.983599
# GRAVITY Z (m/s²)                     -0.120026             14.467933
# LINEAR ACCELERATION Y (m/s²)         -0.203312             76.313301
# GYROSCOPE X (rad/s)                  -0.054370             57.952220
# GYROSCOPE Y (rad/s)                  -0.663375             33.093988
# GYROSCOPE Z (rad/s)                  -0.141489              8.954111

# %% [markdown]
# # Cube Root Trnaformation

# %%
# Calculate initial skewness for negative skewness dataframe
initial_negative_skewness = negative_skew_df.skew()


# Apply cube root transformation to negative skewness dataframe
transformed_negative_skew_df = np.cbrt(negative_skew_df)

# Calculate skewness after transformation
transformed_negative_skewness = transformed_negative_skew_df.skew()


# Compare initial and transformed skewness
skewness_comparison = pd.DataFrame({
    'Initial Skewness': initial_negative_skewness,
    'Transformed Skewness': transformed_negative_skewness
})
print("Comparison of Initial and Transformed Skewness:\n", skewness_comparison)

# Plot histograms and Q-Q plots
def plot_histogram_and_qq(dataframe, title):
    num_cols = dataframe.shape[1]
    plt.figure(figsize=(18, 6 * num_cols))

    for i, column in enumerate(dataframe.columns):
        plt.subplot(num_cols, 2, 2 * i + 1)
        sns.histplot(dataframe[column], kde=True)
        plt.title(f'Histogram of {column}')


    plt.suptitle(f'{title} DataFrame', y=1.02, fontsize=20)
    plt.tight_layout()
    plt.show()

# Plot histograms and Q-Q plots for transformed negative skewness dataframe
plot_histogram_and_qq(transformed_negative_skew_df, '\nTransformed Negative Skewness')
# Out:
# Comparison of Initial and Transformed Skewness:
#                                Initial Skewness  Transformed Skewness
# ACCELEROMETER Z (m/s²)               -0.550701              1.686189
# GRAVITY Z (m/s²)                     -0.120026              1.903639
# LINEAR ACCELERATION Y (m/s²)         -0.203312              0.051689
# GYROSCOPE X (rad/s)                  -0.054370              0.022927
# GYROSCOPE Y (rad/s)                  -0.663375             -0.027374
# GYROSCOPE Z (rad/s)                  -0.141489             -0.043206
